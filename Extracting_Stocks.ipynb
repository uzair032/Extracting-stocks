# %%
import yfinance as yf
tesla_data = yf.download("TSLA", start="2023-01-01", end="2024-01-01")

# Reset index
tesla_data.reset_index(inplace=True)

# Save the DataFrame to a CSV file
tesla_data.to_csv("tesla_stock_data.csv", index=False)

# Display the first five rows of the DataFrame
print(tesla_data.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2023-01-03  118.470001  118.800003  104.639999  108.099998  108.099998
# 1 2023-01-04  109.110001  114.589996  107.519997  113.639999  113.639999
# 2 2023-01-05  110.510002  111.750000  107.160004  110.339996  110.339996
# 3 2023-01-06  103.000000  114.389999  101.809998  113.059998  113.059998
# 4 2023-01-09  118.959999  123.519997  117.110001  119.769997  119.769997
#
#       Volume
# 0  231402800
# 1  180389000
# 2  157986300
# 3  220911100
# 4  190284000

# %%
# Extract revenue data for Tesla
tesla_revenue = yf.Ticker("TSLA").quarterly_financials

# Display the last five rows of the DataFrame
print(tesla_revenue.tail())
# Out:
#                                        2023-12-31     2023-09-30  \
# Selling General And Administration   1280000000.0   1253000000.0
# Gross Profit                         4438000000.0   4178000000.0
# Cost Of Revenue                     20729000000.0  19172000000.0
# Total Revenue                       25167000000.0  23350000000.0
# Operating Revenue                   25167000000.0  23350000000.0
#
#                                        2023-06-30     2023-03-31  \
# Selling General And Administration   1191000000.0   1076000000.0
# Gross Profit                         4533000000.0   4511000000.0
# Cost Of Revenue                     20394000000.0  18818000000.0
# Total Revenue                       24927000000.0  23329000000.0
# Operating Revenue                   24927000000.0  23329000000.0
#
#                                        2022-12-31
# Selling General And Administration   1032000000.0
# Gross Profit                         5777000000.0
# ...

# %%
# Extract stock data for GameStop
gme_data = yf.download("GME", start="2023-01-01", end="2024-01-01")

# Reset index
gme_data.reset_index(inplace=True)

# Save the DataFrame to a CSV file
gme_data.to_csv("gme_stock_data.csv", index=False)

# Display the first five rows of the DataFrame
print(gme_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0 2023-01-03  18.639999  19.260000  17.090000  17.200001  17.200001  5135200
# 1 2023-01-04  17.250000  17.930000  16.900000  17.320000  17.320000  3939300
# 2 2023-01-05  17.059999  17.260000  15.890000  16.219999  16.219999  6066200
# 3 2023-01-06  16.000000  16.570000  15.410000  16.459999  16.459999  4823400
# 4 2023-01-09  16.650000  17.129999  16.360001  16.379999  16.379999  3522600

# %%
# Extract revenue data for GME
gme_revenue = yf.Ticker("GME").quarterly_financials

# Display the last five rows of the DataFrame
print(gme_revenue.tail())
# Out:
#                                       2023-10-31    2023-07-31    2023-04-30  \
# Selling General And Administration   296500000.0   322500000.0   345700000.0
# Gross Profit                         281800000.0   305900000.0   287300000.0
# Cost Of Revenue                      796500000.0   857900000.0   949800000.0
# Total Revenue                       1078300000.0  1163800000.0  1237100000.0
# Operating Revenue                   1078300000.0  1163800000.0  1237100000.0
#
#                                       2023-01-31
# Selling General And Administration   453400000.0
# Gross Profit                         499800000.0
# Cost Of Revenue                     1726600000.0
# Total Revenue                       2226400000.0
# Operating Revenue                   2226400000.0

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot Tesla stock graph
make_graph(tesla_data, title="Tesla Stock Price (2023-2024)")

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price', color='green')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot GameStop stock graph
make_graph(gme_data, title="GameStop Stock Price (2023-2024)")
